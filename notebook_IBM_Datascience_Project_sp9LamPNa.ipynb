# %% [markdown]
# # "My Jupyter Notebook on IBM Data Science Experience"

# %% [markdown]
# **Ojaswi Sinha**
# Data Scientist in healthcare

# %% [markdown]
# _I am highly passionate about data and it occured to me when I worked as a research fellow on a project, where the data has inclined me toward the field of data science. Enthusiastic to follow my passion_

# %% [markdown]
# ### I am writing a code below which will add two numbers and print 'Hey the sum is: '

# %%
a = 5+5
print("Hey the sum is: ", a)
# Out:
# Hey the sum is:  10

# %% [markdown]
# #### Numbered List
# 1. I am new to data science
# 2. I want master it.
# 3. Thanks IBM for the platform

# %% [markdown]
# #### Horizantal line
#
# ***

# %% [markdown]
# #### Bulleted list
# - Hi
# - How are you?

# %% [markdown]
# #### Hyperlink
# [Coursera website](https://www.coursera.org/)

# %% [markdown]
# #### Colors
# <font color=red>Hi, its great to use these markups</font>

# %% [markdown]
# #### Image
# ![download.jpg](attachment:download.jpg)

# %% [markdown]
# #### Blocked quotes
# <code>
#     I love this course
#         <code>

# %% [markdown]
# #### Strikethrough
#
# ~~~Something is wrong~~~
