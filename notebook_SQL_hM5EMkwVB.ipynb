# %%
# !pip install ipython-sql

# %%
# %load_ext sql

# %%
# %sql ibm_db_sa://qmb81927:n038nctfdk-xzkkl@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# Out:
# 'Connected: qmb81927@BLUDB'

# %%
# Rows in Census Data (Socieconimic Indicators)
# %sql SELECT COUNT(*) from census
# Out:
#  * ibm_db_sa://qmb81927:***@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('78'),)]

# %%
# Rows in Public Schools
# %sql SELECT COUNT(*) from Chicago_public_schools
# Out:
#  * ibm_db_sa://qmb81927:***@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# (ibm_db_dbi.ProgrammingError) ibm_db_dbi::ProgrammingError: SQLNumResultCols failed: [IBM][CLI Driver][DB2/LINUXX8664] SQL0204N  "QMB81927.CHICAGO_PUBLIC_SCHOOLS" is an undefined name.  SQLSTATE=42704 SQLCODE=-204 [SQL: 'SELECT COUNT(*) from Chicago_public_schools'] (Background on this error at: http://sqlalche.me/e/f405)

# %%
# Rows in Crime Data
# %sql select count(ID) as "Total_No" from crimeload
# Out:
#  * ibm_db_sa://qmb81927:***@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('533'),)]

# %%
# %sql select * from crimeload LIMIT 10
# Out:
#  * ibm_db_sa://qmb81927:***@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(3512276, 'HK587712', '08/28/2004 05:50:56 PM', '047XX S KEDZIE AVE', '890', 'THEFT', 'FROM BUILDING', 'SMALL RETAIL STORE', 'FALSE', 'FALSE', 911, 9, 14, 58, '6', 1155838, 1873050, 2004, '02/10/2018 03:50:01 PM', Decimal('41.80744050'), Decimal('-87.70395585'), '(41.8074405, -87.703955849)'),
#  (3406613, 'HK456306', '06/26/2004 12:40:00 PM', '009XX N CENTRAL PARK AVE', '820', 'THEFT', '$500 AND UNDER', 'OTHER', 'FALSE', 'FALSE', 1112, 11, 27, 23, '6', 1152206, 1906127, 2004, '02/28/2018 03:56:25 PM', Decimal('41.89827996'), Decimal('-87.71640551'), '(41.898279962, -87.716405505)'),
# ...

# %%
# %sql select count(*) as "arrest num" from crimeload where ARREST=true
# Out:
#  * ibm_db_sa://qmb81927:***@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('163'),)]

# %%
# %sql select unique(primary_type), location_description from crimeload where location_description = 'GAS STATION'
# Out:
#  * ibm_db_sa://qmb81927:***@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('CRIMINAL TRESPA', 'GAS STATION'),
#  ('NARCOTICS', 'GAS STATION'),
#  ('ROBBERY', 'GAS STATION'),
#  ('THEFT', 'GAS STATION')]

# %%
# %sql select COMMUNITY_AREA_NAME from ca where COMMUNITY_AREA_NAME LIKE 'B%'
# Out:
#  * ibm_db_sa://qmb81927:***@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('BEVERLY',),
#  ('BELMONT CRAGIN',),
#  ('BRIGHTON PARK',),
#  ('BRIGHTON PARK',),
#  ('BELMONT CRAGIN',),
#  ('BRIDGEPORT',),
#  ('BELMONT CRAGIN',),
#  ('BRIGHTON PARK',),
#  ('BELMONT CRAGIN',),
#  ('BEVERLY',),
#  ('BRIGHTON PARK',),
#  ('BELMONT CRAGIN',),
#  ('BRIDGEPORT',),
#  ('BELMONT CRAGIN',),
#  ('BURNSIDE',),
#  ('BELMONT CRAGIN',),
#  ('BRIGHTON PARK',),
#  ('BRIGHTON PARK',),
#  ('BEVERLY',),
#  ('BEVERLY',),
#  ('BELMONT CRAGIN',),
#  ('BELMONT CRAGIN',),
#  ('BRIDGEPORT',),
#  ('BELMONT CRAGIN',),
#  ('BELMONT CRAGIN',),
#  ('BRIGHTON PARK',),
#  ('BELMONT CRAGIN',),
#  ('BRIDGEPORT',),
#  ('BRIDGEPORT',),
#  ('BRIGHTON PARK',)]

# %%
# %sql select NAME_OF_SCHOOL from sc where HEALTHY_SCHOOL_CERTIFIED=True and COMMUNITY_AREA_NUMBER between 10 and 15
# Out:
#  * ibm_db_sa://qmb81927:***@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Rufus M Hitch Elementary School',)]

# %%
# %sql select avg(SAFETY_SCORE) as "avg score" from SC
# Out:
#  * ibm_db_sa://qmb81927:***@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('49.504873'),)]

# %%
# %sql select COMMUNITY_AREA_NAME , avg(COLLEGE_ENROLLMENT) as AVG_ENROLLMENT from SC group by COMMUNITY_AREA_NAME order by AVG_ENROLLMENT desc LIMIT 5
# Out:
#  * ibm_db_sa://qmb81927:***@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('ARCHER HEIGHTS', Decimal('2411.500000')),
#  ('MONTCLARE', Decimal('1317.000000')),
#  ('WEST ELSDON', Decimal('1233.333333')),
#  ('BRIGHTON PARK', Decimal('1205.875000')),
#  ('BELMONT CRAGIN', Decimal('1198.833333'))]

# %%
# %sql select COMMUNITY_AREA_NAME, SAFETY_SCORE from SC where SAFETY_SCORE=(select min(SAFETY_SCORE) from SC)
# Out:
#  * ibm_db_sa://qmb81927:***@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('WASHINGTON PARK', 1)]

# %%
# %sql select CD.COMMUNITY_AREA_NAME, CD.PER_CAPITA_INCOME from SC as CPS, ca as CD where CD.COMMUNITY_AREA_NUMBER = CPS.COMMUNITY_AREA_NUMBER and CPS.SAFETY_SCORE = 1
# Out:
#  * ibm_db_sa://qmb81927:***@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# (ibm_db_dbi.ProgrammingError) ibm_db_dbi::ProgrammingError: SQLNumResultCols failed: [IBM][CLI Driver][DB2/LINUXX8664] SQL0206N  "CD.PER_CAPITA_INCOME" is not valid in the context where it is used.  SQLSTATE=42703 SQLCODE=-206 [SQL: 'select CD.COMMUNITY_AREA_NAME, CD.PER_CAPITA_INCOME from SC as CPS, ca as CD where CD.COMMUNITY_AREA_NUMBER = CPS.COMMUNITY_AREA_NUMBER and CPS.SAFETY_SCORE = 1'] (Background on this error at: http://sqlalche.me/e/f405)

# %%
# %sql select ca.COMMUNITY_AREA_NAME, sc.per_capita_income from SC, ca  where ca.COMMUNITY_AREA_NUMBER = sc.COMMUNITY_AREA_NUMBER and sc.SAFETY_SCORE = 1
# Out:
#  * ibm_db_sa://qmb81927:***@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# (ibm_db_dbi.ProgrammingError) ibm_db_dbi::ProgrammingError: SQLNumResultCols failed: [IBM][CLI Driver][DB2/LINUXX8664] SQL0206N  "SC.PER_CAPITA_INCOME" is not valid in the context where it is used.  SQLSTATE=42703 SQLCODE=-206 [SQL: 'select ca.COMMUNITY_AREA_NAME, sc.per_capita_income from SC, ca  where ca.COMMUNITY_AREA_NUMBER = sc.COMMUNITY_AREA_NUMBER and sc.SAFETY_SCORE = 1'] (Background on this error at: http://sqlalche.me/e/f405)

# %%
# %sql select PER_CAPITA_INCOME, COMMUNITY_AREA_NAME from sc;
# Out:
#  * ibm_db_sa://qmb81927:***@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# (ibm_db_dbi.ProgrammingError) ibm_db_dbi::ProgrammingError: SQLNumResultCols failed: [IBM][CLI Driver][DB2/LINUXX8664] SQL0206N  "PER_CAPITA_INCOME" is not valid in the context where it is used.  SQLSTATE=42703 SQLCODE=-206 [SQL: 'select PER_CAPITA_INCOME, COMMUNITY_AREA_NAME from sc;'] (Background on this error at: http://sqlalche.me/e/f405)
